# %% [markdown]
# <a href="https://colab.research.google.com/github/Swathipilli221/Swathipilli221/blob/main/Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2025-03-20 06:18:46--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json.1’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   115MB/s    in 0.6s
#
# 2025-03-20 06:18:47 (115 MB/s) - ‘arxiv-paper-data.json.1’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 3410 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 21752   1406.7638v1  Estimation of density derivatives is a versati...  stat
# 9613    1110.0641v1  There is a growing interest in using a longitu...  stat
# 14820   1107.4734v1  Diacritical marks play a crucial role in meeti...    cs
# 22298  1512.03444v1  Recursive partitioning approaches producing tr...  stat
# 7014   1709.01298v2  Early approaches to multiple-output Gaussian p...  stat
# ...             ...                                                ...   ...
# 27511  1703.09157v1  Many state-of-the-art methods have been propos...    cs
# 13129  1702.08248v1  Coresets are compact representations of data s...  stat
# 20447  1602.02169v1  We can program a Real-Time (RT) music improvis...    cs
# 24264   1211.1800v1  This paper is practically interested in the un...    cs
# 23770   1406.1881v2  Holistic methods based on dense trajectories a...    cs
#
#                                                    title  year  \
# 21752  Direct Density-Derivative Estimation and Its A...  2014
# 9613   Identifying relationships between drugs and me...  2011
# 14820                 Design of Arabic Diacritical Marks  2011
# 22298  Cross-Validated Variable Selection in Tree-Bas...  2015
# 7014   Spectral Mixture Kernels for Multi-Output Gaus...  2017
# ...                                                  ...   ...
# 27511  Reweighted Infrared Patch-Tensor Model With Bo...  2017
# 13129  Scalable and Distributed Clustering via Lightw...  2017
# 20447  Probabilistic Extension to the Concurrent Cons...  2016
# 24264  A Comparative study of Arabic handwritten char...  2012
# 23770  Fine-grained Activity Recognition with Holisti...  2014
#
#                                                 keywords
# 21752  [estimation, derivatives, versatile, statistic...
# 9613   [longitudinal, observational, databases, homog...
# 14820  [diacritical, usability, typographic, homogene...
# 22298  [recursive, partitioning, approaches, producin...
# 7014   [approaches, processes, combinations, independ...
# ...                                                  ...
# 27511  [detection, homogeneous, backgrounds, heteroge...
# 13129  [representations, competitive, successfully, c...
# 20447  [improvisation, deterministic, concurrent, con...
# 24264  [practically, interested, unchangeable, handwr...
# 23770  [trajectories, currently, recognition, activit...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 21752    [estimation, derivatives, versatile, statistic...
# 9613     [longitudinal, observational, databases, homog...
# 14820    [diacritical, usability, typographic, homogene...
# 22298    [recursive, partitioning, approaches, producin...
# 7014     [approaches, processes, combinations, independ...
#                                ...
# 35035    [performance, particularly, execution, functio...
# 40659    [collaborative, filtering, challenges, computi...
# 37926    [extension, hamiltonian, splitting, hamiltonia...
# 22708    [parametric, regression, variables, introduced...
# 3433     [artificial, successfully, including, recognit...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8896 words.
# Out of those 4561 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b4105d0a-c8c4-439a-942b-57064bdcb2a3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b4105d0a-c8c4-439a-942b-57064bdcb2a3")) {                    Plotly.newPlot(                        "b4105d0a-c8c4-439a-942b-57064bdcb2a3",                        [{"x":["dimensional","experimentally","practical","estimating","validation","efficient","approximate","selection","divergence","parametric","demonstrated","derivative","estimation","superiority","detection","improving","versatile","necessarily","parameters","computationally","estimator","statistical","approximation","derivatives","application","objectively","conditions","experience","databases","traditional","organised","construct","longitudinal","comparison","ensembling","relationships","observational","innovation","identifying","classification","different","challenge","recognised","organisers","unlabelled","homogeneous","publications","associations","objective","simulated","performing","justification","complicated","difficulty","positioning","completely","usability","challenging","difficult","processing","resolution","placement","situation","strategies","multilingual","controlled","beginning","homogeneity","essentially","ubiquitous","significantly","replacing","variables","framework","overfitting","increased","approaches","categorical","recursive","predictive","assumptions","computational","algorithm","simulation","demonstrate","validated","inability","performance","reasonable","following","conceptual","contribute","complexity","producing","important","precludes","consequence","manifests","partitioning","fundamental","selecting","categories","importantly","extensive","regression","splitting","informative","combinations","modelling","frequencies","constructed","providing","densities","lengthscales","interpretation","conflicting","magnitudes","understand","multivariate","functions","covariance","covariances","synthetic","differences","processes","principled","rationale","independent","interpret","relationship","expressive","representations","additional","experiments","projection","cambridge","preserving","techniques","riemannian","exploited","expression","descriptors","foreground","multiclass","recognition","structure","superposition","instruments","principle","impossible","financial","inference","discovering","interactions","reciprocity","formulation","auxiliary","empirically","observations","associated","probabilistic","converting","measuring","electronics","reduction","introduces","procedures","illumination","intervals","sinusoidal","performed","halftoning","counterparts","therefore","structured","experimental","significant","motionless","projected","conversion","multiplexed","technique","gradients","consequently","algorithms","languages","differentiable","justifiable","outperforms","arbitrary","variational","approximates","considering","maximizing","optimization","parameterized","solutions","posterior","stochastic","programming"],"y":[191,37,153,61,48,384,114,149,26,35,90,7,212,37,349,102,15,19,265,74,23,173,116,6,246,2,140,40,51,172,3,85,3,135,4,60,4,7,71,489,730,156,4,1,4,20,7,15,169,72,76,11,29,49,7,38,8,243,155,315,104,10,31,93,20,27,7,6,19,11,251,16,146,546,24,35,417,12,22,50,65,275,805,79,536,41,0,895,39,94,22,39,252,31,342,2,20,3,12,79,41,84,24,160,117,12,43,26,58,18,51,80,8,0,63,10,1,62,20,207,30,1,124,61,98,30,3,140,26,60,37,221,109,578,50,3,49,396,12,33,45,45,18,11,341,315,3,11,57,17,9,219,30,74,1,85,17,74,84,111,153,8,29,2,90,70,29,40,17,1,120,2,18,135,95,345,257,3,22,14,2,255,25,28,605,111,25,2,248,99,51,10,70,27,302,14,144,56,110,129],"type":"bar"},{"x":["dimensional","experimentally","practical","estimating","validation","efficient","approximate","selection ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4561,), (4561, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8141666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.4375);'>Discriminative</span> <span style=''>Transfer</span> <span style=''>Learning</span> <span style=''>for</span> <span style=''>General</span> <span style=''>Image</span> <span style='background-color:rgba(0, 255, 0, 0.5555555555555556);'>Restoration</span> <br/><br/><span style=''>Recently</span> <span style=''>several</span> <span style='background-color:rgba(0, 255, 0, 0.4375);'>discriminative</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approaches</span> <span style=''>have</span> <span style=''>been</span> <span style=''>proposed</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3129770992366412);'>effective</span> <span style=''>image</span> <span style='background-color:rgba(0, 255, 0, 0.5555555555555556);'>restoration</span> <span style='background-color:rgba(0, 255, 0, 0.4244604316546763);'>achieving</span> <span style='background-color:rgba(0, 255, 0, 0.5555555555555556);'>convincing</span> <span style=''>trade</span> <span style=''>off</span> <span style=''>between</span> <span style=''>image</span> <span style=''>quality</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computational</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficiency</span> <span style=''>However</span> <span style=''>these</span> <span style=''>methods</span> <span style=''>require</span> <span style=''>separate</span> <span style=''>training</span> <span style=''>for</span> <span style=''>each</span> <span style='background-color:rgba(0, 255, 0, 0.5555555555555556);'>restoration</span> <span style=''>task</span> <span style=''>(eg</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>denoising</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>deblurring</span> <span style=''>demosaicing)</span> <span style=''>and</span> <span style=''>problem</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>condition</span> <span style=''>(eg</span> <span style=''>noise</span> <span style=''>level</span> <span style=''>of</span> <span style=''>input</span> <span style=''>images)</span> <span style=''>This</span> <span style=''>makes</span> <span style=''>it</span> <span style=''>time</span> <span style='background-color:rgba(0, 255, 0, 0.37931034482758624);'>consuming</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>difficult</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>encompass</span> <span style=''>all</span> <span style=''>tasks</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditions</span> <span style=''>during</span> <span style=''>training</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.4375);'>discriminative</span> <span style=''>transfer</span> <span style=''>learning</span> <span style=''>method</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>incorporates</span> <span style=''>formal</span> <span style=''>proximal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.4375);'>discriminative</span> <span style=''>learning</span> <span style=''>for</span> <span style=''>general</span> <span style=''>image</span> <span style='background-color:rgba(0, 255, 0, 0.5555555555555556);'>restoration</span> <span style=''>The</span> <span style=''>method</span> <span style=''>requires</span> <span style=''>a</span> <span style=''>single</span> <span style=''>pass</span> <span style=''>training</span> <span style=''>and</span> <span style=''>allows</span> <span style=''>for</span> <span style=''>reuse</span> <span style=''>across</span> <span  ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Learning</span> <span style=''>with</span> <span style=''>many</span> <span style=''>experts</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>and</span> <span style=''>sparsity</span> <br/><br/><span style=''>Experts</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifying</span> <span style=''>data</span> <span style=''>are</span> <span style=''>often</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>imprecise</span> <span style=''>Recently</span> <span style=''>several</span> <span style=''>models</span> <span style=''>have</span> <span style=''>been</span> <span style=''>proposed</span> <span style=''>to</span> <span style=''>train</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifiers</span> <span style=''>using</span> <span style=''>the</span> <span style=''>noisy</span> <span style=''>labels</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generated</span> <span style=''>by</span> <span style=''>these</span> <span style=''>experts</span> <span style=''>How</span> <span style=''>to</span> <span style=''>choose</span> <span style=''>between</span> <span style=''>these</span> <span style=''>models</span> <span style=''>In</span> <span style=''>such</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>situations</span> <span style=''>the</span> <span style=''>true</span> <span style=''>labels</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>unavailable</span> <span style=''>Thus</span> <span style=''>one</span> <span style=''>cannot</span> <span style=''>perform</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>using</span> <span style=''>the</span> <span style=''>standard</span> <span style=''>versions</span> <span style=''>of</span> <span style=''>methods</span> <span style=''>such</span> <span style=''>as</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>empirical</span> <span style=''>risk</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>minimization</span> <span style=''>and</span> <span style=''>cross</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>validation</span> <span style=''>In</span> <span style=''>order</span> <span style=''>to</span> <span style=''>allow</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>selection</span> <span style=''>we</span> <span style=''>present</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>surrogate</span> <span style=''>loss</span> <span style=''>and</span> <span style=''>provide</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>guarantees</span> <span style=''>that</span> <span style=''>assure</span> <span style=''>its</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>consistency</span> <span style=''>Next</span> <span style=''>we</span> <span style=''>discuss</span> <span style=''>how</span> <span style=''>this</span> <span style=''>loss</span> <span style=''>can</span> <span style=''>be</span> <span style=''>used</span> <span style=''>to</span> <span style=''>tune</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>penalization</span> <span style=''>which</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduces</span> <span style=''>sparsity</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameters</span> <span style=''>of</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>traditional</span> <span style=''>class</span> <span style=''>of</span> <span style=''>models</span> <span style=''>Sparsity</span> <span style=''>provides</span> <span style=''>more</span> <span style='background-color:rgba(0, 2 ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3855670103092783);'>Knowledge</span> <span style=''>Transfer</span> <span style=''>with</span> <span style=''>Jacobian</span> <span style=''>Matching</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Classical</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>distillation</span> <span style=''>methods</span> <span style=''>transfer</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>representations</span> <span style=''>from</span> <span style=''>a</span> <span style=''>teacher</span> <span style=''>neural</span> <span style=''>network</span> <span style=''>to</span> <span style=''>a</span> <span style=''>student</span> <span style=''>network</span> <span style=''>by</span> <span style=''>matching</span> <span style=''>their</span> <span style=''>output</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>activations</span> <span style=''>Recent</span> <span style=''>methods</span> <span style=''>also</span> <span style=''>match</span> <span style=''>the</span> <span style=''>Jacobians</span> <span style=''>or</span> <span style=''>the</span> <span style=''>gradient</span> <span style=''>of</span> <span style=''>output</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>activations</span> <span style=''>with</span> <span style=''>the</span> <span style=''>input</span> <span style=''>However</span> <span style=''>this</span> <span style=''>involves</span> <span style=''>making</span> <span style=''>some</span> <span style=''>ad</span> <span style=''>hoc</span> <span style='background-color:rgba(0, 255, 0, 0.43661971830985913);'>decisions</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>particular</span> <span style=''>the</span> <span style=''>choice</span> <span style=''>of</span> <span style=''>the</span> <span style=''>loss</span> <span style=''>function</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>first</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>establish</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3170731707317074);'>equivalence</span> <span style=''>between</span> <span style=''>Jacobian</span> <span style=''>matching</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>distillation</span> <span style=''>with</span> <span style=''>input</span> <span style=''>noise</span> <span style=''>from</span> <span style=''>which</span> <span style=''>we</span> <span style=''>derive</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>appropriate</span> <span style=''>loss</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>functions</span> <span style=''>for</span> <span style=''>Jacobian</span> <span style=''>matching</span> <span style=''>We</span> <span style=''>then</span> <span style=''>rely</span> <span style=''>on</span> <span style=''>this</span> <span style=''>analysis</span> <span style=''>to</span> <span style=''>apply</span> <span style=''>Jacobian</span> <span style=''>matching</span> <span style=''>to</span> <span style=''>transfer</span> <span style=''>learning</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>establishing</span> <span style='background-color:rgba(0, 255, 0, 0.3170731707317074);'>equivalence</span> <span style=''>of</span> <span style=''>a</span> <span style=''>recent</span> <span style=''>transfer</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>procedure</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>distillation</span> <span style=''>We</span> <span style=''>then</span> <span style=''>show</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>experimentally</span> <span style=''>on</span> <span style=''>standard</span> ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Learning</span> <span style=''>with</span> <span style=''>Bounded</span> <span style=''>Instance</span> <span style=''>and</span> <span style=''>Label</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dependent</span> <span style=''>Label</span> <span style=''>Noise</span> <br/><br/><span style=''>Instance</span> <span style=''>and</span> <span style=''>label</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dependent</span> <span style=''>label</span> <span style=''>noise</span> <span style=''>(ILN)</span> <span style=''>is</span> <span style=''>widely</span> <span style=''>existed</span> <span style=''>in</span> <span style=''>real</span> <span style=''>world</span> <span style=''>datasets</span> <span style=''>but</span> <span style=''>has</span> <span style=''>been</span> <span style=''>rarely</span> <span style=''>studied</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>focus</span> <span style=''>on</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>particular</span> <span style=''>case</span> <span style=''>of</span> <span style=''>ILN</span> <span style=''>where</span> <span style=''>the</span> <span style=''>label</span> <span style=''>noise</span> <span style=''>rates</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representing</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>probabilities</span> <span style=''>that</span> <span style=''>the</span> <span style=''>true</span> <span style=''>labels</span> <span style=''>of</span> <span style=''>examples</span> <span style=''>flip</span> <span style=''>into</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>corrupted</span> <span style=''>labels</span> <span style=''>have</span> <span style=''>upper</span> <span style=''>bounds</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>to</span> <span style=''>handle</span> <span style=''>this</span> <span style=''>bounded</span> <span style=''>instance</span> <span style=''>and</span> <span style=''>label</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dependent</span> <span style=''>label</span> <span style=''>noise</span> <span style=''>under</span> <span style=''>two</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conditions</span> <span style=''>First</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>theoretically</span> <span style=''>we</span> <span style=''>prove</span> <span style=''>that</span> <span style=''>when</span> <span style=''>the</span> <span style=''>marginal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributions</span> <span style=''>P(X|Y1)</span> <span style=''>and</span> <span style=''>P(X|Y</span> <span style=''>1)</span> <span style=''>have</span> <span style=''>non</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>overlapping</span> <span style=''>supports</span> <span style=''>we</span> <span style=''>can</span> <span style=''>recover</span> <span style=''>every</span> <span style=''>noisy</span> <span style=''>examples</span> <span style=''>true</span> <span style=''>label</span> <span style=''>and</span> <span style=''>perform</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>supervised</span> <span style=''>learning</span> <span style=''>directly</span> <span style=''>on</span> <span style=''>the</span> <span style=''>cleansed</span> <span style=''>examples</span> <span style=''>Second</span> <span style=''>for</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>overlapping</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>situation</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>ap ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	knowledge (0.1207764198418404)
# 	evaluation (0.098490294751977)
# 	information (0.2426312005751258)
# 	architecture (0.09813084112149532)
# 	processing (0.11322789360172537)
# 	segmentation (0.08015815959741193)
# 	detection (0.12544931703810208)
# 	recognition (0.12257368799424874)
# 	different (0.26240115025161753)
# 	convolutional (0.12904385334291876)
#
# Some Statistics words are:
# 	algorithm (0.37462834489593655)
# 	variables (0.13825569871159563)
# 	stochastic (0.12586719524281467)
# 	estimation (0.16253716551040634)
# 	distributions (0.12289395441030723)
# 	theoretical (0.14618434093161545)
# 	distribution (0.18136769078295342)
# 	inference (0.1937561942517344)
# 	dimensional (0.18681863230921705)
# 	regression (0.17641228939544104)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="0f50fdad-10e4-4762-ae06-7c13753416ce" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0f50fdad-10e4-4762-ae06-7c13753416ce")) {                    Plotly.newPlot(                        "0f50fdad-10e4-4762-ae06-7c13753416ce",                        [{"x":["dimensional","experimentally","practical","estimating","validation","efficient","approximate","selection","divergence","parametric","demonstrated","derivative","estimation","superiority","detection","improving","versatile","necessarily","parameters","computationally","estimator","statistical","approximation","derivatives","application","objectively","conditions","experience","databases","traditional","organised","construct","longitudinal","comparison","ensembling","relationships","observational","innovation","identifying","classification","different","challenge","recognised","organisers","unlabelled","homogeneous","publications","associations","objective","simulated","performing","justification","complicated","difficulty","positioning","completely","usability","challenging","difficult","processing","resolution","placement","situation","strategies","multilingual","controlled","beginning","homogeneity","essentially","ubiquitous","significantly","replacing","variables","framework","overfitting","increased","approaches","categorical","recursive","predictive","assumptions","computational","algorithm","simulation","demonstrate","validated","inability","performance","reasonable","following","conceptual","contribute","complexity","producing","important","precludes","consequence","manifests","partitioning","fundamental","selecting","categories","importantly","extensive","regression","splitting","informative","combinations","modelling","frequencies","constructed","providing","densities","lengthscales","interpretation","conflicting","magnitudes","understand","multivariate","functions","covariance","covariances","synthetic","differences","processes","principled","rationale","independent","interpret","relationship","expressive","representations","additional","experiments","projection","cambridge","preserving","techniques","riemannian","exploited","expression","descriptors","foreground","multiclass","recognition","structure","superposition","instruments","principle","impossible","financial","inference","discovering","interactions","reciprocity","formulation","auxiliary","empirically","observations","associated","probabilistic","converting","measuring","electronics","reduction","introduces","procedures","illumination","intervals","sinusoidal","performed","halftoning","counterparts","therefore","structured","experimental","significant","motionless","projected","conversion","multiplexed","technique","gradients","consequently","algorithms","languages","differentiable","justifiable","outperforms","arbitrary","variational","approximates","considering","maximizing","optimization","parameterized","solutions","posterior","stochastic","programming","distribution","efficiently","importance","evaluated","estimates","insightful","promising","competing","knowledge","answering","interaction","improvements","paraphrase","effective","retrieval","combining","effectively","furthermore","simultaneously","identification","specifically","disambiguate","sequences","agglomerative","continuity","integrate","minimization","egocentric","integrating","segmentation","performances","guarantee","clustering","constrained","benchmarks","localizes","components","benchmark","properties","correlation","mechanism","correlational","proportional","convolutional","employing","throughput","compatible","architectures","characteristics","optimizations","improvement","delivered","deploying","internals","derivation","composi ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	inability
# 	lengthscales
# 	traintest
# 	circumvents
# 	coregionalization
# 	macroeconomic
# 	metabolite
# 	unidentifiability
# 	subdifferential
# 	backfitting
# 	unprocessed
# 	molecules
# 	underestimation
# 	closeness
# 	parametrically
# 	cheminformatics
# 	practiced
# 	readmission
# 	administrative
# 	identifiability
# Some words which never appear in Statistics papers:
# 	cambridge
# 	electronics
# 	illumination
# 	halftoning
# 	motionless
# 	multiplexed
# 	paraphrase
# 	disambiguate
# 	egocentric
# 	optimizations
# 	delivered
# 	internals
# 	annotating
# 	interrelations
# 	submitted
# 	transformers
# 	anticipating
# 	geospatial
# 	abductive
# 	professionals

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.088230752601835e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.77
